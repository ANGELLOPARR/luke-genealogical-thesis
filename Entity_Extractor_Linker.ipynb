# %%
# !python --version
# Out:
# Python 3.7.11

# %%
# !python -m pip install spacy==2.1.0
# !pip install neuralcoref
# !python -m spacy download en_core_web_lg

# %% [markdown]
# ## You have to restart runtime here :c

# %%
import pandas as pd
import numpy as np

# %%
# Load your usual SpaCy model (one of SpaCy English models)
import spacy
import re
nlp = spacy.load('en_core_web_lg')

# Add neural coref to SpaCy's pipeline
import neuralcoref
neuralcoref.add_to_pipe(nlp)

# %%
def clean_wikitext(text):
    cleaned = re.sub(r'\[.{1,2}\]', '', text)
    cleaned = re.sub(r'\(([^\)]*[^\)]*?)\)', '', cleaned)
    return cleaned
    
clean_wikitext('Maria "Maja" Einstein (18 November 1881 – 25 June 1951) and her older brother, Albert, were the two children of Hermann Einstein and Pauline Einstein (née Koch), who had moved from Ulm to Munich in June 1881, when Albert was one.[14] There Hermann and his brother Jakob had founded Einstein & Cie., an electrical ')
# Out:
# 'Maria "Maja" Einstein  and her older brother, Albert, were the two children of Hermann Einstein and Pauline Einstein , who had moved from Ulm to Munich in June 1881, when Albert was one. There Hermann and his brother Jakob had founded Einstein & Cie., an electrical '

# %%
# You're done. You can now use NeuralCoref as you usually manipulate a SpaCy document annotations.
# doc = nlp(u'Kimberly Noel Kardashian was born on October 21, 1980, in Los Angeles, California, to Robert and Kris Kardashian. She has an older sister, Kourtney, a younger sister, Khloé, and a younger brother, Rob. Their mother is of Dutch, English, Irish, and Scottish ancestry, while their father was a third-generation Armenian-American. After their parents divorced in 1991, her mother married again that year, to Bruce Jenner, the 1976 Summer Olympics decathlon winner. Through their marriage, Kim Kardashian gained step-brothers Burton "Burt", Brandon, and Brody; step-sister Casey; and half-sisters Kendall and Kylie Jenner.')
doc = nlp(clean_wikitext('Maria "Maja" Einstein (18 November 1881 – 25 June 1951) and her older brother, Albert, were the two children of Hermann Einstein and Pauline Einstein (née Koch), who had moved from Ulm to Munich in June 1881, when Albert was one.[14] There Hermann and his brother Jakob had founded Einstein & Cie., an electrical engineering company.[15]'))
display(doc._.has_coref)
display(doc._.coref_clusters)
# display(doc._.coref_scores)
clusters = doc._.coref_clusters
# Out:
# True
# [Maria "Maja" Einstein: [Maria "Maja" Einstein, her], Hermann: [Hermann, his]]

# %%
[d for d in doc.ents if d.label_ == 'PERSON']
# Out:
# [Maria "Maja" Einstein,
#  Albert,
#  Hermann Einstein,
#  Pauline Einstein,
#  Albert,
#  Hermann,
#  Jakob]

# %%
clusters[3].main.ents
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/1c/k2wn77c50k9bqdzb_sjw90600000gn/T/ipykernel_51082/3196661731.py in <module>
# ----> 1 clusters[3].main.ents
#
# IndexError: list index out of range

# %%
# Remove all clusters that don't have a named entity in the main resolved span
clusters = [c for c in clusters if len(c.main.ents) > 0]

# Remove all clusters that don't contain a PERSON named entity in the main resolved span
clusters = [c for c in clusters if len([c_ent for c_ent in c.main.ents if c_ent.label_ == 'PERSON']) > 0]

# TODO: Find a way to parse out people from groups (older sister, Kourtney, a younger sister, Khloé)
# and include their coreferences by part.
clusters
# Out:
# [Maria "Maja" Einstein: [Maria "Maja" Einstein, her], Hermann: [Hermann, his]]

# %%
display(doc._.coref_clusters[0].main)
display(doc._.coref_clusters[0].mentions)

# %%
type(doc._.coref_clusters[0])

# %%
found_entities = [(e, doc[:0]) for e in doc.ents if e.label_ == 'PERSON']
display(found_entities[:5])
type(found_entities[0])
# Out:
# [(Maria "Maja" Einstein, ),
#  (Albert, ),
#  (Hermann Einstein, ),
#  (Pauline Einstein, ),
#  (Albert, )]
# tuple

# %%
# TODO: Might need to abstract found_entities to include who the entities are linke to (if any)
for c in clusters:
    for ment in c.mentions:
        if ment != c.main and (ment, c.main) not in found_entities:
            found_entities.append((ment, c.main))

display(found_entities)
# Out:
# [(Maria "Maja" Einstein, ),
#  (Albert, ),
#  (Hermann Einstein, ),
#  (Pauline Einstein, ),
#  (Albert, ),
#  (Hermann, ),
#  (Jakob, ),
#  (her, Maria "Maja" Einstein),
#  (his, Hermann)]

# %%
MAX_RANGE = 140

for (ent1, coref1) in found_entities:
    for (ent2, coref2) in found_entities:
        if ent2 == ent1 or coref2 == ent1 or coref1 == ent2:
            continue

        if ent2.end_char <= ent1.start_char + MAX_RANGE and ent1.start_char < ent2.start_char:
            print(f'ENT 1 ({ent1}), ENT 2 ({ent2})')
            rel_span = doc.text[ent1.start_char : ent2.end_char]
            encoded_e1 = f'[e1] {ent1.text} [/e1]'
            encoded_e2 = f'[e2] {ent2.text} [/e2]'
            # print(ent1.start_char)
            # print(rel_span[: ent1.start_char])
            # second_half = f'{encoded_e2} {rel_span[ent2.end_char]}'
            new_span = encoded_e1 + doc.text[ent1.end_char : ent2.start_char] + encoded_e2
            print(new_span)

# %%
pd.read_excel('NER_test.xlsx')['Entities'].to_list()[0].split(',')
# Out:
# ['Albert Einstein',
#  ' Hermann Einstein',
#  ' Pauline Koch',
#  ' Einstein',
#  ' Jakob']

# %%
entities = pd.read_excel('NER_test.xlsx')
entities['cleaned_text'] = entities['Text'].apply(clean_wikitext)
entities['true_entities'] = entities['Entities'].apply(split_entities)
entities['predicted_entities'] = entities['cleaned_text'].apply(find_entities)
entities['predicted_entities'] = entities['predicted_entities'].apply(split_entities)
entities
# Out:
#                                                 Text  \
# 0  Albert Einstein was born in Ulm,[7] in the Kin...
# 1  Maria "Maja" Einstein (18 November 1881 – 25 J...
# 2  Kimberly Noel Kardashian was born on October 2...
# 3  Peter Michael Davidson[4] was born on November...
# 4  Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5  Prince Rogers Nelson was born in Minneapolis, ...
# 6  Louis Sedell Hayes was born in Detroit, Michig...
# 7  Coltrane was born in his parents' apartment at...
#
#                                             Entities
# 0  Albert Einstein, Hermann Einstein, Pauline Koc...
# 1  Maria "Maja" Einstein, Albert, Hermann Einstei...
# 2  Kimberly Noel Kardashian, Robert, Kris Kardash...
# 3  Peter Michael Davidson, Amy, Scott Matthew Dav...
# 4  Kid Cudi, Scott Ramon Seguro Mescudi, Domingo,...
# 5  Prince Rogers Nelson, Mattie Della, John Lewis...
# 6  Louis Sedell Hayes, John Nelson, Prince, Hayes...
# 7            Coltrane, John R. Coltrane, Alice Blair

# %%
entities['cleaned_text'] = entities['Text'].apply(clean_wikitext)
entities
# Out:
#                                                 Text  \
# 0  Albert Einstein was born in Ulm,[7] in the Kin...
# 1  Maria "Maja" Einstein (18 November 1881 – 25 J...
# 2  Kimberly Noel Kardashian was born on October 2...
# 3  Peter Michael Davidson[4] was born on November...
# 4  Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5  Prince Rogers Nelson was born in Minneapolis, ...
# 6  Louis Sedell Hayes was born in Detroit, Michig...
# 7  Coltrane was born in his parents' apartment at...
#
#                                             Entities  \
# 0  Albert Einstein, Hermann Einstein, Pauline Koc...
# 1  Maria "Maja" Einstein, Albert, Hermann Einstei...
# 2  Kimberly Noel Kardashian, Robert, Kris Kardash...
# 3  Peter Michael Davidson, Amy, Scott Matthew Dav...
# 4  Kid Cudi, Scott Ramon Seguro Mescudi, Domingo,...
# 5  Prince Rogers Nelson, Mattie Della, John Lewis...
# 6  Louis Sedell Hayes, John Nelson, Prince, Hayes...
# 7            Coltrane, John R. Coltrane, Alice Blair
#
#                                         cleaned_text
# 0  Albert Einstein was born in Ulm, in the Kingdo...
# 1  Maria "Maja" Einstein  and her older brother, ...
# 2  Kimberly Noel Kardashian was born on October 2...
# 3  Peter Michael Davidson was born on November 16...
# 4  Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5  Prince Rogers Nelson was born in Minneapolis, ...
# 6  Louis Sedell Hayes was born in Detroit, Michig...
# 7  Coltrane was born in his parents' apartment at...

# %%
def find_entities(wikitext):
    doc = nlp(wikitext)
    entities = [d for d in doc.ents if d.label_ == 'PERSON']
    return ', '.join([str(e) for e in entities])

def split_entities(ent_string):
    arr = ent_string.split(',')
    return [e.strip() for e in arr]

# %%
entities['true_entities'] = entities['Entities'].apply(split_entities)

# %%
entities['predicted_entities'] = entities['cleaned_text'].apply(find_entities)
entities['predicted_entities'] = entities['predicted_entities'].apply(split_entities)

# %%
entities
# Out:
#                                                 Text  \
# 0  Albert Einstein was born in Ulm,[7] in the Kin...
# 1  Maria "Maja" Einstein (18 November 1881 – 25 J...
# 2  Kimberly Noel Kardashian was born on October 2...
# 3  Peter Michael Davidson[4] was born on November...
# 4  Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5  Prince Rogers Nelson was born in Minneapolis, ...
# 6  Louis Sedell Hayes was born in Detroit, Michig...
# 7  Coltrane was born in his parents' apartment at...
#
#                                             Entities  \
# 0  Albert Einstein, Hermann Einstein, Pauline Koc...
# 1  Maria "Maja" Einstein, Albert, Hermann Einstei...
# 2  Kimberly Noel Kardashian, Robert, Kris Kardash...
# 3  Peter Michael Davidson, Amy, Scott Matthew Dav...
# 4  Kid Cudi, Scott Ramon Seguro Mescudi, Domingo,...
# 5  Prince Rogers Nelson, Mattie Della, John Lewis...
# 6  Louis Sedell Hayes, John Nelson, Prince, Hayes...
# 7            Coltrane, John R. Coltrane, Alice Blair
#
#                                         cleaned_text  \
# 0  Albert Einstein was born in Ulm, in the Kingdo...
# 1  Maria "Maja" Einstein  and her older brother, ...
# 2  Kimberly Noel Kardashian was born on October 2...
# 3  Peter Michael Davidson was born on November 16...
# 4  Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5  Prince Rogers Nelson was born in Minneapolis, ...
# 6  Louis Sedell Hayes was born in Detroit, Michig...
# 7  Coltrane was born in his parents' apartment at...
#
#                                        true_entities  \
# 0  [Albert Einstein, Hermann Einstein, Pauline Ko...
# 1  [Maria "Maja" Einstein, Albert, Hermann Einste...
# 2  [Kimberly Noel Kardashian, Robert, Kris Kardas...
# 3  [Peter Michael Davidson, Amy, Scott Matthew Da...
# 4  [Kid Cudi, Scott Ramon Seguro Mescudi, Domingo...
# 5  [Prince Rogers Nelson, Mattie Della, John Lewi...
# 6  [Louis Sedell Hayes, John Nelson, Prince, Haye...
# 7          [Coltrane, John R. Coltrane, Alice Blair]
#
#                                   predicted_entities
# 0  [Albert Einstein, Hermann Einstein, Pauline Ko...
# 1  [Maria "Maja" Einstein, Albert, Hermann Einste...
# 2  [Kimberly Noel Kardashian, Robert, Kris Kardas...
# 3  [Peter Michael Davidson, Amy, Scott Matthew Da...
# 4  [Kid Cudi, Scott Ramon Seguro Mescudi, Solon, ...
# 5  [Prince Rogers Nelson, Mattie Della, John Lewi...
# 6  [Louis Sedell Hayes, John Nelson, Prince, Haye...
# 7  [Coltrane, John R. Coltrane, Alice Blair, Will...

# %%
entities['predicted_entities'][3]
# Out:
# ['Peter Michael Davidson',
#  'Amy',
#  'Scott Matthew Davidson',
#  'Requiem Mass',
#  'Great Kills']

# %%
entities['true_entities'][3]
# Out:
# ['Peter Michael Davidson', 'Amy', 'Scott Matthew Davidson']

# %%
entities
# Out:
#                                                  Text  \
# 0   Albert Einstein was born in Ulm,[7] in the Kin...
# 1   Maria "Maja" Einstein (18 November 1881 – 25 J...
# 2   Kimberly Noel Kardashian was born on October 2...
# 3   Peter Michael Davidson[4] was born on November...
# 4   Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5   Prince Rogers Nelson was born in Minneapolis, ...
# 6   Louis Sedell Hayes was born in Detroit, Michig...
# 7   Coltrane was born in his parents' apartment at...
# 8   Heath was born in Philadelphia on October 25, ...
# 9   Heath originally played alto saxophone. He ear...
# 10  He briefly joined Miles Davis's group in 1959,...
# 11  Thompson was born into a middle-class family i...
# 12  Wenner was born in New York City, the son of S...
# 13  In the summer of 1967, after Rolling Stone sta...
# 4   [Kid Cudi, Scott Ramon Seguro Mescudi, Domingo...
# 5   [Prince Rogers Nelson, Mattie Della, John Lewi...
# 6   [Louis Sedell Hayes, John Nelson, Prince, Haye...
# 7           [Coltrane, John R. Coltrane, Alice Blair]
# 8           [Heath, Heath, Percy Heath, Albert Heath]
# 9   [Heath, Howard McGhee, Dizzy Gillespie, Charli...
# 10  [Miles Davis, Coltrane, Kenny Dorham, Gil Evan...
# 11  [Thompson, Virginia Davison Ray, Jack Robert T...
# 12  [Wenner, Sim, Edwawrd Wenner, Kate, Merlyn, We...
# 13  [Wenner, Jane Schindelheim, Wenner, Jane Wenne...
# 14  [Wenner, Matt Nye, Wenner, Nye, Noah, Jude, In...
# 15  [Bob Dylan, Robert Allen Zimmerman, Dylan, Ann...
# 16  [Dylan, Little Richard, Elvis Presley, Dylan, ...
# 17  [Grace Brewster Murray, Walter Fletcher Murray...
# 18  [Margaret Elaine Heafield, Kenneth Heafield, R...
# 19  [Katherine Johnson, Creola Katherine Coleman, ...
#
#                                    predicted_entities
# 0   [Albert Einstein, Hermann Einstein, Pauline Ko...
# 1   [Maria "Maja" Einstein, Albert, Hermann Einste...
# 2   [Kimberly Noel Kardashian, Robert, Kris Kardas...
# 3   [Peter Michael Davidson, Amy, Scott Matthew Da...
# 4   [Kid Cudi, Scott Ramon Seguro Mescudi, Solon, ...
# 5   [Prince Rogers Nelson, Mattie Della, John Lewi...
# 6   [Louis Sedell Hayes, John Nelson, Prince, Haye...
# 7   [Coltrane, John R. Coltrane, Alice Blair, Will...
# 8                         [Percy Heath, Albert Heath]
# 9    [Howard McGhee, Dizzy Gillespie, Charlie Parker]
# 10  [Miles Davis's, Coltrane, Kenny Dorham, Gil Ev...
# 11  [Davison Ray, Jack Robert Thompson, Jack, Nich...
# 12                      [Edward Wenner, Kate, Merlyn]
# 13  [Jane Schindelheim, Wenner, Jane Wenner, Alexa...
# 14                [Matt Nye, Wenner, Nye, Noah, Jude]
# 15  [Bob Dylan, Robert Allen Zimmerman, Dylan, Ann...
# 16  [Little Richard, Elvis Presley, Dylan, Robert ...
# 17  [Grace Brewster Murray, Walter Fletcher Murray...
# 18  [Margaret Elaine Heafield, Kenneth Heafield, R...
# 19  [Katherine Johnson, Katherine Coleman, Joylett...

# %%
def evaluate_NER(true_entities, predicted_entities):
    tp, fp, fn = 0, 0, 0
    fp_arr = []
    fn_arr = []
    # print(true_entities)
    for i in range(len(true_entities)):
        true = copy.deepcopy(true_entities[i])
        preds = copy.deepcopy(predicted_entities[i])
        for e in preds:
            if e in true:
                # print(f'{e} in {true} -- TRUE')
                # preds.remove(e)
                true.remove(e)
                tp += 1
            else:
                # print(f'{e} in {true} -- FALSE')
                # preds.remove(e)
                fp_arr.append(e)
                fp += 1
        for et in true:
            fn_arr.append(et)
        fn += len(true)
    return ({'precision': tp / (tp + fp), 'recall': tp / (tp + fn)}, {'tp' : tp, 'fp': fp, 'fn': fn}, {'fp_arr': fp_arr, 'fn_arr': fn_arr})
    return tp, fp, fn

# %%
entities = pd.read_excel('NER_test.xlsx')
entities['cleaned_text'] = entities['Text'].apply(clean_wikitext)
entities['true_entities'] = entities['Entities'].apply(split_entities)
entities['predicted_entities'] = entities['cleaned_text'].apply(find_entities)
entities['predicted_entities'] = entities['predicted_entities'].apply(split_entities)
entities
# Out:
#                                                  Text  \
# 0   Albert Einstein was born in Ulm,[7] in the Kin...
# 1   Maria "Maja" Einstein (18 November 1881 – 25 J...
# 2   Kimberly Noel Kardashian was born on October 2...
# 3   Peter Michael Davidson[4] was born on November...
# 4   Kid Cudi was born Scott Ramon Seguro Mescudi i...
# 5   Prince Rogers Nelson was born in Minneapolis, ...
# 6   Louis Sedell Hayes was born in Detroit, Michig...
# 7   Coltrane was born in his parents' apartment at...
# 8   Heath was born in Philadelphia on October 25, ...
# 9   Heath originally played alto saxophone. He ear...
# 10  He briefly joined Miles Davis's group in 1959,...
# 11  Thompson was born into a middle-class family i...
# 12  Wenner was born in New York City, the son of S...
# 13  In the summer of 1967, after Rolling Stone sta...
# 14  Since 1995, Wenner's domestic partner has been...
# 15  Bob Dylan was born Robert Allen Zimmerman (Heb...
# 16  Dylan formed several bands while attending Hib...
# 17  Grace Brewster Murray was born in New York Cit...
# 18  Margaret Elaine Heafield was born August 17, 1...
# 19  Katherine Johnson was born as Creola Katherine...
#
#                                              Entities  \
# 0   Albert Einstein, Hermann Einstein, Pauline Koc...
# 1   Maria "Maja" Einstein, Albert, Hermann Einstei...
# 2   Kimberly Noel Kardashian, Robert, Kris Kardash...
# 3   Peter Michael Davidson, Amy, Scott Matthew Dav...
# 4   Kid Cudi, Scott Ramon Seguro Mescudi, Domingo,...
# 5   Prince Rogers Nelson, Mattie Della, John Lewis...
# 6   Louis Sedell Hayes, John Nelson, Prince, Hayes...
# 7             Coltrane, John R. Coltrane, Alice Blair
# 8             Heath, Heath, Percy Heath, Albert Heath
# 9   Heath, Howard McGhee, Dizzy Gillespie, Charlie...
# 10  Miles Davis, Coltrane, Kenny Dorham, Gil Evans...
# 11  Thompson, Virginia Davison Ray, Jack Robert Th...
# 12   Wenner, Sim, Edward Wenner, Kate, Merlyn, Wenner
# 13  Wenner, Jane Schindelheim, Wenner, Jane Wenner...
# 14  Wenner, Matt Nye, Wenner, Nye, Noah, Jude, Ind...
# 15  Bob Dylan, Robert Allen Zimmerman, Dylan, Anna...
# 16  Dylan, Little Richard, Elvis Presley, Dylan, R...
# 17  Grace Brewster Murray, Walter Fletcher Murray,...
# 18  Margaret Elaine Heafield, Kenneth Heafield, Ru...
# 19  Katherine Johnson, Creola Katherine Coleman, J...
#
#                                          cleaned_text  \
# 0   Albert Einstein was born in Ulm, in the Kingdo...
# 1   Maria "Maja" Einstein  and her older brother, ...
# 2   Kimberly Noel Kardashian was born on October 2...
# 12                      [Edward Wenner, Kate, Merlyn]
# 13  [Jane Schindelheim, Wenner, Jane Wenner, Alexa...
# 14                [Matt Nye, Wenner, Nye, Noah, Jude]
# 15  [Bob Dylan, Robert Allen Zimmerman, Dylan, Ann...
# 16  [Little Richard, Elvis Presley, Dylan, Robert ...
# 17  [Grace Brewster Murray, Walter Fletcher Murray...
# 18  [Margaret Elaine Heafield, Kenneth Heafield, R...
# 19  [Katherine Johnson, Katherine Coleman, Joylett...

# %%
import copy
gt = copy.deepcopy(entities['true_entities'].values)
preds = copy.deepcopy(entities['predicted_entities'].values)

# %%
evaluate_NER(gt, preds)
# Out:
# ({'precision': 0.8951612903225806, 'recall': 0.8222222222222222},
#  {'tp': 111, 'fp': 13, 'fn': 24},
#  {'fp_arr': ['Requiem Mass',
#    'Great Kills',
#    'Solon',
#    'Prince',
#    "Horace Silver's",
#    'the Oscar Peterson Trio',
#    'William Penn High School',
#    "Miles Davis's",
#    'Davison Ray',
#    'Theodore',
#    'Simon',
#    'Richard',
#    'Katherine Coleman'],
#   'fn_arr': ['Einstein',
#    'Khloé',
#    'Domingo',
#    'Philly Joe Jones',
#    'Horace Silver',
#    'Cannonnball Adderly',
#    'Oscar Peterson',
#    'Heath',
#    'Heath',
#    'Heath',
#    'Miles Davis',
#    'Virginia Davison Ray',
#    'Thompson',
#    'Wenner',
#    'Sim',
#    'Wenner',
#    'Wenner',
#    'Theodore "Theo" Simon',
#    'Wenner',
#    'India Rose',
#    'Florence',
#    'Little Richard',
#    'Dylan',
#    'Creola Katherine Coleman']})

# %%
import pandas as pd
import numpy as np

data = '~/Downloads/data (18).json'

df = pd.read_json(data)
df
# Out:
#                                                  text         label  \
# 0   [e1] Kimberly Noel Kardashian [/e1] was born o...  PARENT-CHILD
# 1   [e1] Kimberly Noel Kardashian [/e1] was born o...  PARENT-CHILD
# 2   [e1] She [/e1] has an older sister, [e2] Kourt...      SIBLINGS
# 3   [e1] She [/e1] has an older sister, Kourtney, ...      SIBLINGS
# 4   [e1] She [/e1] has an older sister, Kourtney, ...      SIBLINGS
# ..                                                ...           ...
# 83  [e1] She [/e1] was the daughter of [e2] David ...  PARENT-CHILD
# 84  [e1] She [/e1] had three sisters, [e2] Hanna [...      SIBLINGS
# 85  [e1] She [/e1] had three sisters, Hanna, [e2] ...      SIBLINGS
# 86  [e1] She [/e1] had three sisters, Hanna, Marga...      SIBLINGS
# 87  [e1] Hanna [/e1]'s husband, the well-known pac...      MARRIAGE
#
#                                         baseParagraph
# 0
# 1
# 2
# 3
# 4
# ..                                                ...
# 83  Conor Cruise O'Brien was born at 44 Leinster R...
# 84  Conor Cruise O'Brien was born at 44 Leinster R...
# 85  Conor Cruise O'Brien was born at 44 Leinster R...
# 86  Conor Cruise O'Brien was born at 44 Leinster R...
# 87  Conor Cruise O'Brien was born at 44 Leinster R...
#
# [88 rows x 3 columns]
